# %% [markdown]
# <a href="https://colab.research.google.com/github/bashriyashik151-spec/ict_assignments/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#assignment 2
#question 1
for i in range(1,100):
  if i%3==0:
    print("fizz")
  elif i%5==0:
    print("buzz")
  elif i%3==0 and i%5==0:
    print("fizzbuzz")
  else:
    print(i)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz

# %%
#question 2
a = int(input('num of units consumed'))
if a<=100:
  bill = a*5
  print("total bill amount:",bill)
elif a<=200:
  bill=(100*5)+((a-100)*7)
  print("total bill amout:",bill)
else:
    bill=(100*5)+(100*7)+((a-200)*10)
    print("total bill amount:",bill)
# Out:
# num of units consumed245
# total bill amount: 1650

# %%
#question 3
y = "*"
for i in range(1,6):
  print(y*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
#question 4
a=input('enter a num or string:')
if a==a[::-1]:
  print('the given  num or string is palindrome')
else:
  print('the given num or string is not palindrome')
# Out:
# enter a num or string:121
# the given  num or string is palindrome
